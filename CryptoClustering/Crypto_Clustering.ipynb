# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import holoviews as hv

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
columns_to_scale = ['price_change_percentage_24h', 'price_change_percentage_7d', 'price_change_percentage_14d',
                    'price_change_percentage_30d', 'price_change_percentage_60d', 'price_change_percentage_200d',
                    'price_change_percentage_1y']

scaled_data = StandardScaler().fit_transform(df_market_data[columns_to_scale])

# %%
# Create a DataFrame with the scaled data
df_scaled_data = pd.DataFrame(
    scaled_data,
    columns=columns_to_scale,
    index=df_market_data.index
)

# Display sample data
df_scaled_data.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Data.

# %%
# Create a list with the number of k-values from 1 to 11
k_values = list(range(1, 11))

# %%
# Create an empty list to store the inertia values
inertia_values = []


# Create a for loop to compute the inertia with each possible value of k, Inside the loop:
for k in k_values:
    # 1. Create a KMeans model using the loop counter for the n_clusters
    kmeans = KMeans(n_clusters=k, random_state=42)
    
    # 2. Fit the model to the data using `df_market_data_scaled`
    kmeans.fit(df_scaled_data)
    
    # 3. Append the model.inertia_ to the inertia list
    inertia_values.append(kmeans.inertia_)
# Out:
# /Users/owner/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/owner/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/owner/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data = {
    "k": k_values,
    "inertia": inertia_values
}


# Create a DataFrame with the data to plot the Elbow curve
df_elbow = pd.DataFrame(elbow_data)

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
elbow_plot = df_elbow.hvplot.line(x="k", y="inertia", title="Elbow Curve", xticks=k_values)
elbow_plot
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** 4

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Data

# %%
# Initialize the K-Means model using the best value for k
kmeans = KMeans(n_clusters=4, random_state=42)

# %%
# Fit the K-Means model using the scaled data
kmeans.fit(df_scaled_data)
# Out:
# /Users/owner/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=4, random_state=42)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data
crypto_clusters = kmeans.predict(df_scaled_data)


# Print the resulting array of cluster values.
crypto_clusters
# Out:
# array([0, 0, 2, 2, 0, 0, 0, 0, 0, 2, 2, 2, 2, 0, 2, 0, 2, 2, 0, 2, 2, 0,
#        2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 3, 0, 2, 2, 1, 2, 2, 2, 2],
#       dtype=int32)

# %%
# Create a copy of the DataFrame
df_market_data_copy = df_market_data.copy()

# %%
# Add a new column to the DataFrame with the predicted clusters
df_market_data_copy['cluster'] = crypto_clusters

# Display sample data
df_market_data_copy.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                           1.08388                     7.60278
# ethereum                          0.22392                    10.38134
# tether                           -0.21173                     0.04935
# ripple                           -0.37819                    -0.60926
# bitcoin-cash                      2.90585                    17.09717
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                           6.57509                      7.67258
# ethereum                          4.80849                      0.13169
# tether                            0.00640                     -0.04237
# ripple                            2.24984                      0.23455
# bitcoin-cash                     14.75334                     15.74903
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using hvPlot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`. 
# Color the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.

scatter_plot = df_market_data_copy.hvplot.scatter(
    x='price_change_percentage_24h',
    y='price_change_percentage_7d',
    by='cluster',
    hover_cols=['coin_id'],
    title='Cryptocurrency Clusters',
    xlabel='Price Change Percentage (24h)',
    ylabel='Price Change Percentage (7d)',
    width=700,
    height=500
)

# Display the scatter plot
scatter_plot
# Out:
# :NdOverlay   [cluster]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce to 
# three principal components.
crypto_pca_df = pd.DataFrame(
    pca.fit_transform(df_scaled_data),
    columns=['PC1', 'PC2', 'PC3'],
    index=df_scaled_data.index
)
# View the first five rows of the DataFrame. 
crypto_pca_df.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %%
# Retrieve the explained variance to determine how much information 
# can be attributed to each principal component.
explained_variance = pca.explained_variance_ratio_

# Print the explained variance for each principal component
print("Explained Variance:")
for i, variance in enumerate(explained_variance):
    print(f"PC{i+1}: {variance:.4f}")
# Out:
# Explained Variance:
# PC1: 0.3720
# PC2: 0.3470
# PC3: 0.1760

# %%
total_explained_variance = sum(explained_variance)
print(f"{total_explained_variance:.4f}")
# Out:
# 0.8950

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:** 0.8950, or 89.50%. This means that the three principal components together explain 89.50% of the variance in the original data.

# %%
# Create a new DataFrame with the PCA data.

# Creating a DataFrame with the PCA data
pca_df = pd.DataFrame(
    data=crypto_pca_df,
    columns=['PC1', 'PC2', 'PC3']
)
# Copy the crypto names from the original data
pca_df['coin_id'] = df_market_data_copy.index

# Set the coinid column as index
pca_df.set_index('coin_id', inplace=True)


# Display sample data
pca_df.head()
# Out:
#                    PC1       PC2       PC3
# coin_id
# bitcoin      -0.600667  0.842760  0.461595
# ethereum     -0.458261  0.458466  0.952877
# tether       -0.433070 -0.168126 -0.641752
# ripple       -0.471835 -0.222660 -0.479053
# bitcoin-cash -1.157800  2.041209  1.859715

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values from 1 to 11
k_values = list(range(1, 11))

# %%
# Create an empty list to store the inertia values
inertia_values = []

# Create a for loop to compute the inertia with each possible value of k
# Inside the loop:
for k in k_values:
    # Create a KMeans model using the loop counter for the n_clusters
    kmeans = KMeans(n_clusters=k, random_state=42)
    
    # 2. Fit the model to the data using pca_df
    kmeans.fit(pca_df)
    
    # 3. Append the model.inertia_ to the inertia list
    inertia_values.append(kmeans.inertia_)
# Out:
# /Users/owner/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/owner/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /Users/owner/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
# Create a dictionary with the data to plot the Elbow curve
pca_elbow_data = {
    'k': k_values,
    'inertia': inertia_values
}
# Create a DataFrame with the data to plot the Elbow curve
pca_elbow_df = pd.DataFrame(elbow_data)

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.
pca_elbow_plot = pca_elbow_df.hvplot.line(x='k', y='inertia', title='Elbow Curve (PCA Data)', xticks=k_values)
pca_elbow_plot
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** 4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** The best value for k when using the original data was also determined to be 4. This means that the optimal number of clusters is consistent between the original data and the PCA-transformed data.

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
kmeans_pca = KMeans(n_clusters=4, random_state=42)

# %%
# Fit the K-Means model using the PCA data
kmeans_pca.fit(pca_df)
# Out:
# /Users/owner/anaconda3/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=4, random_state=42)

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data
pca_clusters = kmeans_pca.predict(pca_df)


# Print the resulting array of cluster values.
pca_clusters
# Out:
# array([0, 0, 2, 2, 0, 0, 0, 0, 0, 2, 2, 2, 2, 0, 2, 0, 2, 2, 0, 2, 2, 0,
#        2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 3, 0, 2, 2, 1, 2, 2, 2, 2],
#       dtype=int32)

# %%
# Create a copy of the DataFrame with the PCA data
pca_clusters = kmeans.predict(pca_df)


# Add a new column to the DataFrame with the predicted clusters
pca_df['cluster'] = pca_clusters

# Display sample data
pca_df.head()
# Out:
#                    PC1       PC2       PC3  cluster
# coin_id
# bitcoin      -0.600667  0.842760  0.461595        8
# ethereum     -0.458261  0.458466  0.952877        8
# tether       -0.433070 -0.168126 -0.641752        3
# ripple       -0.471835 -0.222660 -0.479053        3
# bitcoin-cash -1.157800  2.041209  1.859715        6

# %%
# Create a scatter plot using hvPlot by setting 
# `x="PC1"` and `y="PC2"`. 
# Color the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.
cluster_plot = pca_df.hvplot.scatter(
   x="PC1",
   y="PC2",
   hover_cols=["coin_id"],
   by="cluster",
   cmap="Viridis"
)

cluster_plot
# Out:
# :NdOverlay   [cluster]
#    :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
# Composite plot to contrast the Elbow curves

# Create the elbow curve plots
elbow_plot = df_elbow.hvplot.line(x="k", y="inertia", title="Elbow Curve", xticks=k_values)
pca_elbow_plot = elbow_df.hvplot.line(x='k', y='inertia', title='Elbow Curve (PCA Data)', xticks=k_values)

# Convert the elbow curve plots to HoloViews objects
elbow_curve = hv.render(elbow_plot, backend='bokeh')
pca_elbow_curve = hv.render(pca_elbow_plot, backend='bokeh')

# Combine the two elbow curve plots into a composite layout
composite_plot = (elbow_plot + pca_elbow_plot).cols(1)

# Display the composite plot
composite_plot
# Out:
# :Layout
#    .Curve.I  :Curve   [k]   (inertia)
#    .Curve.II :Curve   [k]   (inertia)

# %%
# Composite plot to contrast the clusters
# Create the scatter plots
scatter_plot = df_market_data_copy.hvplot.scatter(
    x='price_change_percentage_24h',
    y='price_change_percentage_7d',
    by='cluster',
    hover_cols=['coin_id'],
    title='Cryptocurrency Clusters',
    xlabel='Price Change Percentage (24h)',
    ylabel='Price Change Percentage (7d)',
    width=700,
    height=500
)

cluster_plot = pca_df.hvplot.scatter(
    x="PC1",
    y="PC2",
    hover_cols=["coin_id"],
    by="cluster",
    cmap="Viridis"
)

# Convert the scatter plots to HoloViews objects
original_scatter = hv.render(scatter_plot, backend='bokeh')
pca_scatter = hv.render(cluster_plot, backend='bokeh')

# Combine the two scatter plots into a composite layout
composite_plot = (scatter_plot + cluster_plot).cols(1)

# Display the composite plot
composite_plot
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [cluster]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [cluster]
#       :Scatter   [PC1]   (PC2,coin_id)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:** The key things to consider are:
#
# 1. Separation and Compactness of Clusters: Observe how well the data points are separated into distinct clusters and how compact or spread out the clusters are in both the original data and the PCA data scatter plots. Better-defined and more compact clusters generally indicate a more effective clustering.
#
# 2. Cluster Assignments: Compare the cluster assignments of individual data points (cryptocurrencies) between the two scatter plots. Are the same cryptocurrencies grouped into the same clusters, or are there significant differences in the cluster assignments?
#
# 3. Dimensionality Reduction: The PCA scatter plot uses the first two principal components (PC1 and PC2) as the x and y axes, representing a reduced dimensionality of the original feature space. Assess whether this dimensionality reduction has led to a loss of important information or has helped in better separating the clusters.
#
# * It's important to note that the impact of using fewer features (principal components) can vary depending on the specific dataset and the nature of the features. In some cases, dimensionality reduction can improve the clustering performance, while in others, it may degrade the results. Visual analysis and comparison of the cluster analysis results can help in understanding the trade-offs and determining the appropriate approach for a given dataset.
